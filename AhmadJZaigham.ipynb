# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Ahmad J Zaigham
# Data Scientist

# %% [markdown]
# ### I am interested in Data Science because I love to gain insights from data.

# %% [markdown]
# #### The following formula shows summation of number

# %%
def Gauss(n):
    return(n*(n+1))/2
Gauss(100) == sum(range(101))
# Out:
# True

# %% [markdown]
# Ahmad
# Jalees
# Zaigham
# Ahmad
# Jalees
# Zaigham
#
# ![272566763_10160126189634511_378477773103373375_n.jpg](attachment:272566763_10160126189634511_378477773103373375_n.jpg)
